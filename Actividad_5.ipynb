# %% [markdown]
# <a href="https://colab.research.google.com/github/coordinadorpf-prog/ModelosAnaliticosUnicafam202607/blob/main/Actividad_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **INTRODUCCION A PYTHON**
#
# **MODELOS ANALITICOS**
# **VALORES DE CADENA**
#
# **UNICAFAM**
#
# **DOCENTE:NICOLAS MOJICA**
#
# **ESTUDIANTE:DALIA ZULUAGA**

# %% [markdown]
# EJERCICIO 5: VALORES DE CADENA

# %%
# DECLARACION DE CADENA
saludo="hola, mundo!"
print(saludo)
# Out:
# hola, mundo!

# %%
# PRIMER CARACTER DE LA CADENA
print(saludo[0])
# Out:
# h

# %%
# ULTIMOS CARACTERES DE LA CADENA
print(saludo[-5:])
# Out:
# undo!

# %%
# CONCATENACION DE CADENAS
saludo_completo=saludo+ ",¿cómo estás?"
print(saludo_completo)
# Out:
# hola, mundo!,¿cómo estás?

# %%
# CONVERSION A MAYUSCULAS
saludo_mayusculas=saludo_completo.upper()
print(saludo_mayusculas)
# Out:
# HOLA, MUNDO!,¿CÓMO ESTÁS?

# %%
# REEMPLAZO DE LA PALABRA
saludo_reemplazo=saludo_completo.replace("mundo", "Python")
print(saludo_reemplazo)
# Out:
# hola, Python!,¿cómo estás?
