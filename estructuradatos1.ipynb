# %% [markdown]
# <a href="https://colab.research.google.com/github/coordinadorpf-prog/ModelosAnaliticosUnicafam202607/blob/main/estructuradatos1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ESTRUCTURAS DE DATOS
#
# MODELOS ANALITICOS
#
# UNICAFAM
#
# DOCENTE:NICOLAS MOJICA
#
# ESTUDIANTE:DALIA ZULUAGA
#
# EJERCICIO # 1

# %%
# 1. Crear lista con números del 1 al 5
numeros=[1,2,3,4,5]
print("lista original",numeros)
# Out:
# lista original [1, 2, 3, 4, 5]

# %%
# 2. Añadir el número 6 al final
numeros.append(6)
print("lista original",numeros)
# Out:
# lista original [1, 2, 3, 4, 5, 6]

# %%
# 3. Cambiar el segundo elemento a 10
numeros[1]=10
print("lista original",numeros)
# Out:
# lista original [1, 10, 3, 4, 5, 6]

# %%
# 4. Eliminar el cuarto elemento
numeros.pop(3)
print("lista original",numeros)
# Out:
# lista original [1, 10, 3, 5, 6]
