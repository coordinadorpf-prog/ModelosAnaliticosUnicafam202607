# %% [markdown]
# <a href="https://colab.research.google.com/github/coordinadorpf-prog/ModelosAnaliticosUnicafam202607/blob/main/Ejercicio_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **EJERCICIO 4: OPERADORES MATEMATICOS**

# %%
#1.DECLARACION DE VARIABLES
a=10
b=3

# %%
# SUMA
suma= a+b
print(suma)
# Out:
# 13

# %%
# RESTA
resta=a-b
print(resta)
# Out:
# 7

# %%
# MULTIPLICACION
multiplicacion=(a*b)
print(multiplicacion)
# Out:
# 30

# %%
# DIVISION
division=a/b
print(division)
# Out:
# 3.3333333333333335

# %%
from binascii import b2a_base64
# MODULO
modulo=a%b
print(modulo)
# Out:
# 1

# %%
# POTENCIA
potencia=a**b
print(potencia)
# Out:
# 1000

# %%
# DIVISION ENTERA
division_entera=a//b
print(division_entera)
# Out:
# 3
